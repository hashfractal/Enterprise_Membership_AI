# %%
#6.1.1 LeNet

# %%
# %load_ext tensorboard

import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Dropout

# %%
num_classes = 2
class LeNet(Sequential):
    def __init__(self, input_shape, nb_classes):
        super().__init__()

        self.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape, padding="same"))
        self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
        self.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))
        self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
        self.add(Flatten())
        self.add(Dense(120, activation='relu'))
        self.add(Dense(84, activation='relu'))
        self.add(Dense(nb_classes, activation='softmax'))

        self.compile(optimizer='adam',
                    loss=categorical_crossentropy,
                    metrics=['accuracy'])

# %%
model = LeNet((100, 100, 3), num_classes)
model.summary()
# Out:
# Model: "le_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 6)       456
#
#  average_pooling2d (AverageP  (None, 50, 50, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 23, 23, 16)       0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 8464)              0
#
#  dense (Dense)               (None, 120)               1015800
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 2)                 170
#
# =================================================================
# Total params: 1,029,006
# Trainable params: 1,029,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE = 32
image_height = 100
image_width = 100
train_dir = "../chap6/data/catanddog/train/"
valid_dir = "../chap6/data/catanddog/validation/"

# %%
train = ImageDataGenerator(
                  rescale=1./255,
                  rotation_range=10,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  shear_range=0.1,
                  zoom_range=0.1)

train_generator = train.flow_from_directory(train_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=1,
                                                    shuffle=True,
                                                    class_mode="categorical")

valid = ImageDataGenerator(rescale=1.0/255.0)
valid_generator = valid.flow_from_directory(valid_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=7,
                                                    shuffle=True,
                                                    class_mode="categorical"
                                                    )
train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.

# %%
log_dir="../chap6/img/log6-1/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 0)

# %%
model.fit(train_generator,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_generator,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=[tensorboard_callback],
                    verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 115ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 2.4726 - val_accuracy: 0.6250
# Epoch 2/100
# 12/12 [==============================] - 1s 114ms/step - loss: 0.0491 - accuracy: 0.9858 - val_loss: 2.3880 - val_accuracy: 0.6458
# Epoch 3/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0379 - accuracy: 0.9830 - val_loss: 2.4115 - val_accuracy: 0.6250
# Epoch 4/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0647 - accuracy: 0.9858 - val_loss: 2.5322 - val_accuracy: 0.6458
# Epoch 5/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.0468 - accuracy: 0.9887 - val_loss: 2.4107 - val_accuracy: 0.6250
# Epoch 6/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0682 - accuracy: 0.9745 - val_loss: 2.4539 - val_accuracy: 0.6354
# Epoch 7/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0295 - accuracy: 0.9870 - val_loss: 2.4669 - val_accuracy: 0.6250
# Epoch 8/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0370 - accuracy: 0.9858 - val_loss: 2.5478 - val_accuracy: 0.6146
# Epoch 9/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0214 - accuracy: 0.9972 - val_loss: 2.5974 - val_accuracy: 0.6458
# Epoch 10/100
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0235 - accuracy: 0.9887 - val_loss: 2.5128 - val_accuracy: 0.6458
# Epoch 11/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0149 - accuracy: 0.9972 - val_loss: 2.3476 - val_accuracy: 0.7083
# Epoch 12/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0162 - accuracy: 0.9943 - val_loss: 2.6283 - val_accuracy: 0.6354
# Epoch 13/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0362 - accuracy: 0.9943 - val_loss: 2.5661 - val_accuracy: 0.5938
# Epoch 14/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0297 - accuracy: 0.9915 - val_loss: 2.6780 - val_accuracy: 0.6354
# Epoch 15/100
# 12/12 [==============================] - 1s 98ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 2.7027 - val_accuracy: 0.6667
# Epoch 16/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.0405 - accuracy: 0.9887 - val_loss: 2.8201 - val_accuracy: 0.6771
# Epoch 17/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0134 - accuracy: 0.9972 - val_loss: 2.8673 - val_accuracy: 0.6250
# Epoch 18/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0408 - accuracy: 0.9887 - val_loss: 2.7187 - val_accuracy: 0.6250
# Epoch 19/100
# 12/12 [==============================] - 1s 97ms/step - loss: 0.0745 - accuracy: 0.9802 - val_loss: 2.5558 - val_accuracy: 0.5938
# Epoch 20/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0257 - accuracy: 0.9915 - val_loss: 2.2972 - val_accuracy: 0.6250
# Epoch 21/100
# 12/12 [==============================] - 1s 122ms/step - loss: 0.1195 - accuracy: 0.9688 - val_loss: 2.2239 - val_accuracy: 0.6354
# Epoch 22/100
# 12/12 [==============================] - 2s 144ms/step - loss: 0.0299 - accuracy: 0.9858 - val_loss: 2.3016 - val_accuracy: 0.6146
# Epoch 23/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 2.2834 - val_accuracy: 0.6354
# Epoch 24/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0360 - accuracy: 0.9802 - val_loss: 2.2901 - val_accuracy: 0.6562
# Epoch 25/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 2.1524 - val_accuracy: 0.6979
# Epoch 26/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0253 - accuracy: 0.9887 - val_loss: 2.2997 - val_accuracy: 0.6875
# Epoch 27/100
# 12/12 [==============================] - 1s 116ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 2.5424 - val_accuracy: 0.6771
# Epoch 28/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.5838 - val_accuracy: 0.6562
# Epoch 29/100
# 12/12 [==============================] - 1s 116ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 2.5952 - val_accuracy: 0.6667
# Epoch 30/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.0225 - accuracy: 0.9972 - val_loss: 2.6111 - val_accuracy: 0.6250
# Epoch 31/100
# 12/12 [==============================] - 1s 111ms/step - loss: 0.0190 - accuracy: 0.9915 - val_loss: 2.5046 - val_accuracy: 0.6875
# Epoch 32/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.0193 - accuracy: 0.9915 - val_loss: 2.1833 - val_accuracy: 0.6667
# Epoch 33/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0221 - accuracy: 0.9943 - val_loss: 2.3879 - val_accuracy: 0.6146
# Epoch 34/100
# 12/12 [==============================] - 2s 126ms/step - loss: 0.0857 - accuracy: 0.9632 - val_loss: 2.7511 - val_accuracy: 0.6667
# Epoch 35/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0873 - accuracy: 0.9773 - val_loss: 2.9047 - val_accuracy: 0.6146
# Epoch 36/100
# 12/12 [==============================] - 1s 124ms/step - loss: 0.1120 - accuracy: 0.9717 - val_loss: 2.5717 - val_accuracy: 0.6562
# Epoch 37/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0785 - accuracy: 0.9745 - val_loss: 2.2087 - val_accuracy: 0.5833
# Epoch 38/100
# 12/12 [==============================] - 1s 112ms/step - loss: 0.0794 - accuracy: 0.9802 - val_loss: 2.0881 - val_accuracy: 0.6146
# Epoch 39/100
# 12/12 [==============================] - 1s 111ms/step - loss: 0.0910 - accuracy: 0.9660 - val_loss: 2.0220 - val_accuracy: 0.6146
# Epoch 40/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0701 - accuracy: 0.9688 - val_loss: 1.9549 - val_accuracy: 0.6354
# Epoch 41/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0426 - accuracy: 0.9802 - val_loss: 2.1546 - val_accuracy: 0.5938
# Epoch 42/100
# 12/12 [==============================] - 1s 116ms/step - loss: 0.0324 - accuracy: 0.9915 - val_loss: 2.3728 - val_accuracy: 0.6250
# Epoch 43/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0759 - accuracy: 0.9717 - val_loss: 1.8118 - val_accuracy: 0.6250
# Epoch 44/100
# 12/12 [==============================] - 1s 118ms/step - loss: 0.3021 - accuracy: 0.8867 - val_loss: 1.5071 - val_accuracy: 0.6042
# Epoch 45/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.3875 - accuracy: 0.8499 - val_loss: 1.4924 - val_accuracy: 0.6146
# Epoch 46/100
# 12/12 [==============================] - 2s 132ms/step - loss: 0.2085 - accuracy: 0.9150 - val_loss: 1.2400 - val_accuracy: 0.6042
# Epoch 47/100
# 12/12 [==============================] - 2s 129ms/step - loss: 0.1047 - accuracy: 0.9603 - val_loss: 1.4055 - val_accuracy: 0.6146
# Epoch 48/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.1063 - accuracy: 0.9518 - val_loss: 1.4618 - val_accuracy: 0.6146
# Epoch 49/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.0874 - accuracy: 0.9688 - val_loss: 1.6714 - val_accuracy: 0.6146
# Epoch 50/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0754 - accuracy: 0.9714 - val_loss: 1.5856 - val_accuracy: 0.6250
# Epoch 51/100
# 12/12 [==============================] - 1s 114ms/step - loss: 0.0655 - accuracy: 0.9858 - val_loss: 1.6803 - val_accuracy: 0.6250
# Epoch 52/100
# 12/12 [==============================] - 1s 116ms/step - loss: 0.0626 - accuracy: 0.9773 - val_loss: 1.5288 - val_accuracy: 0.6458
# Epoch 53/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0728 - accuracy: 0.9688 - val_loss: 1.8821 - val_accuracy: 0.6042
# Epoch 54/100
# 12/12 [==============================] - 1s 114ms/step - loss: 0.0720 - accuracy: 0.9717 - val_loss: 1.8367 - val_accuracy: 0.6354
# Epoch 55/100
# 12/12 [==============================] - 1s 113ms/step - loss: 0.0550 - accuracy: 0.9745 - val_loss: 2.0200 - val_accuracy: 0.6146
# Epoch 56/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3689 - accuracy: 0.8754 - val_loss: 1.8060 - val_accuracy: 0.6146
# Epoch 57/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.1951 - accuracy: 0.9037 - val_loss: 1.5824 - val_accuracy: 0.6354
# Epoch 58/100
# 12/12 [==============================] - 2s 131ms/step - loss: 0.1803 - accuracy: 0.9235 - val_loss: 1.9773 - val_accuracy: 0.5312
# Epoch 59/100
# 12/12 [==============================] - 1s 118ms/step - loss: 0.1831 - accuracy: 0.9377 - val_loss: 1.6211 - val_accuracy: 0.5729
# Epoch 60/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.1391 - accuracy: 0.9462 - val_loss: 1.5035 - val_accuracy: 0.6146
# Epoch 61/100
# 12/12 [==============================] - 1s 108ms/step - loss: 0.0861 - accuracy: 0.9745 - val_loss: 1.5325 - val_accuracy: 0.6562
# Epoch 62/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0763 - accuracy: 0.9745 - val_loss: 1.7533 - val_accuracy: 0.6042
# Epoch 63/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.1348 - accuracy: 0.9547 - val_loss: 1.7673 - val_accuracy: 0.6354
# Epoch 64/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0720 - accuracy: 0.9632 - val_loss: 1.6976 - val_accuracy: 0.6562
# Epoch 65/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0922 - accuracy: 0.9575 - val_loss: 1.7818 - val_accuracy: 0.6146
# Epoch 66/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0795 - accuracy: 0.9773 - val_loss: 1.7025 - val_accuracy: 0.6458
# Epoch 67/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.0587 - accuracy: 0.9830 - val_loss: 1.6498 - val_accuracy: 0.6667
# Epoch 68/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.0706 - accuracy: 0.9773 - val_loss: 1.6058 - val_accuracy: 0.6979
# Epoch 69/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0385 - accuracy: 0.9915 - val_loss: 1.5644 - val_accuracy: 0.6771
# Epoch 70/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 1.6737 - val_accuracy: 0.6562
# Epoch 71/100
# 12/12 [==============================] - 1s 127ms/step - loss: 0.0345 - accuracy: 0.9858 - val_loss: 1.6321 - val_accuracy: 0.6875
# Epoch 72/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0324 - accuracy: 0.9887 - val_loss: 1.6663 - val_accuracy: 0.6771
# Epoch 73/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0241 - accuracy: 0.9943 - val_loss: 1.7271 - val_accuracy: 0.6979
# Epoch 74/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.0245 - accuracy: 0.9887 - val_loss: 1.8591 - val_accuracy: 0.6875
# Epoch 75/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 1.8055 - val_accuracy: 0.6771
# Epoch 76/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0213 - accuracy: 0.9915 - val_loss: 1.9670 - val_accuracy: 0.6458
# Epoch 77/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0185 - accuracy: 0.9972 - val_loss: 1.9365 - val_accuracy: 0.6458
# Epoch 78/100
# 12/12 [==============================] - 1s 117ms/step - loss: 0.0468 - accuracy: 0.9887 - val_loss: 2.1002 - val_accuracy: 0.6667
# Epoch 79/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0220 - accuracy: 0.9943 - val_loss: 2.0076 - val_accuracy: 0.6875
# Epoch 80/100
# 12/12 [==============================] - 1s 110ms/step - loss: 0.0477 - accuracy: 0.9858 - val_loss: 2.0705 - val_accuracy: 0.6562
# Epoch 81/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.0216 - accuracy: 0.9915 - val_loss: 2.0734 - val_accuracy: 0.6458
# Epoch 82/100
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0170 - accuracy: 0.9915 - val_loss: 2.0693 - val_accuracy: 0.6667
# Epoch 83/100
# 12/12 [==============================] - 1s 121ms/step - loss: 0.0228 - accuracy: 0.9915 - val_loss: 1.9770 - val_accuracy: 0.6875
# Epoch 84/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.0234 - accuracy: 0.9887 - val_loss: 2.0752 - val_accuracy: 0.6875
# Epoch 85/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0150 - accuracy: 0.9972 - val_loss: 2.0811 - val_accuracy: 0.6667
# Epoch 86/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 2.1308 - val_accuracy: 0.6354
# Epoch 87/100
# 12/12 [==============================] - 1s 109ms/step - loss: 0.0147 - accuracy: 0.9943 - val_loss: 2.2759 - val_accuracy: 0.6458
# Epoch 88/100
# 12/12 [==============================] - 1s 111ms/step - loss: 0.0207 - accuracy: 0.9943 - val_loss: 2.2545 - val_accuracy: 0.6250
# Epoch 89/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.0415 - accuracy: 0.9887 - val_loss: 2.1570 - val_accuracy: 0.6667
# Epoch 90/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0185 - accuracy: 0.9887 - val_loss: 2.1265 - val_accuracy: 0.6771
# Epoch 91/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0251 - accuracy: 0.9887 - val_loss: 2.0006 - val_accuracy: 0.6771
# Epoch 92/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 2.1617 - val_accuracy: 0.6562
# Epoch 93/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.0317 - accuracy: 0.9915 - val_loss: 2.1505 - val_accuracy: 0.6979
# Epoch 94/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.0705 - val_accuracy: 0.6667
# Epoch 95/100
# 12/12 [==============================] - 1s 115ms/step - loss: 0.0215 - accuracy: 0.9972 - val_loss: 2.0384 - val_accuracy: 0.6771
# Epoch 96/100
# 12/12 [==============================] - 1s 125ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 2.1732 - val_accuracy: 0.6979
# Epoch 97/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 2.0563 - val_accuracy: 0.6771
# Epoch 98/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.0235 - accuracy: 0.9943 - val_loss: 2.2183 - val_accuracy: 0.6667
# Epoch 99/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 2.0904 - val_accuracy: 0.6562
# Epoch 100/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.0126 - accuracy: 0.9943 - val_loss: 2.0380 - val_accuracy: 0.6875

# %%
class_names = ['cat', 'dog']
validation, label_batch  = next(iter(valid_generator))
prediction_values = model.predict(validation)
prediction_values = np.argmax(prediction_values, axis=1)

fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(8):
    ax = fig.add_subplot(2, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(validation[i,:],cmap=plt.cm.gray_r, interpolation='nearest')
      
    if prediction_values[i] == np.argmax(label_batch[i]):
        ax.text(3, 17, class_names[prediction_values[i]], color='yellow', fontsize=14)
    else:
        ax.text(3, 17, class_names[prediction_values[i]], color='red', fontsize=14)
# Out:
# 1/1 [==============================] - 0s 100ms/step

# %%
#6.1.3 AlexNet

# %%
# %load_ext tensorboard

import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
num_classes = 2
class AlexNet(Sequential):
    def __init__(self, input_shape, num_classes):
        super().__init__()

        self.add(Conv2D(96, kernel_size=(11,11), strides= 4,
                        padding= 'valid', activation= 'relu',
                        input_shape= input_shape,
                        kernel_initializer= 'he_normal'))
        self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None))

        self.add(Conv2D(256, kernel_size=(5,5), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
        self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None)) 

        self.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
        self.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))

        self.add(Conv2D(256, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))

        self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None))

        self.add(Flatten())
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dense(1000, activation= 'relu'))
        self.add(Dense(num_classes, activation= 'softmax'))

        self.compile(optimizer= tf.keras.optimizers.Adam(0.001),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %%
model = AlexNet((100, 100, 3), num_classes)
model.summary()
# Out:
# Model: "alex_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 23, 23, 96)        34944
#
#  max_pooling2d (MaxPooling2D  (None, 11, 11, 96)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 384)         885120
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 384)         1327488
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 256)         884992
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 4096)              4198400
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dense_5 (Dense)             (None, 1000)              4097000
#
#  dense_6 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 28,825,914
# Trainable params: 28,825,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE = 32
image_height = 100
image_width = 100
train_dir = "../chap6/data/catanddog/train/"
valid_dir = "../chap6/data/catanddog/validation/"

# %%
train = ImageDataGenerator(
                  rescale=1./255,
                  rotation_range=10,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  shear_range=0.1,
                  zoom_range=0.1)

train_generator = train.flow_from_directory(train_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=1,
                                                    shuffle=True,
                                                    class_mode="categorical")

valid = ImageDataGenerator(rescale=1.0/255.0)
valid_generator = valid.flow_from_directory(valid_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=7,
                                                    shuffle=True,
                                                    class_mode="categorical"
                                                    )
train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.

# %%
log_dir="../chap6/img/log6-2/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 0)

# %%
model.fit(train_generator,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_generator,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=[tensorboard_callback],
                    verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 7s 594ms/step - loss: 11.0654 - accuracy: 0.4561 - val_loss: 0.7079 - val_accuracy: 0.5000
# Epoch 2/100
# 12/12 [==============================] - 8s 646ms/step - loss: 0.6976 - accuracy: 0.5071 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/100
#
- val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 63/100
# 12/12 [==============================] - 8s 626ms/step - loss: 0.6964 - accuracy: 0.4703 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 64/100
# 12/12 [==============================] - 8s 637ms/step - loss: 0.6951 - accuracy: 0.4844 - val_loss: 0.6920 - val_accuracy: 0.5104
# Epoch 65/100
# 12/12 [==============================] - 7s 614ms/step - loss: 0.6836 - accuracy: 0.5326 - val_loss: 0.7422 - val_accuracy: 0.4896
# Epoch 66/100
# 12/12 [==============================] - 7s 624ms/step - loss: 0.6917 - accuracy: 0.5241 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 67/100
# 12/12 [==============================] - 7s 622ms/step - loss: 0.6927 - accuracy: 0.5212 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 68/100
# 12/12 [==============================] - 9s 711ms/step - loss: 0.6959 - accuracy: 0.4958 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 69/100
# 12/12 [==============================] - 8s 643ms/step - loss: 0.6931 - accuracy: 0.5156 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 70/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.6917 - accuracy: 0.5382 - val_loss: 0.6945 - val_accuracy: 0.4896
# Epoch 71/100
# 12/12 [==============================] - 7s 619ms/step - loss: 0.6929 - accuracy: 0.5212 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 72/100
# 12/12 [==============================] - 7s 618ms/step - loss: 0.6927 - accuracy: 0.5042 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 73/100
# 12/12 [==============================] - 8s 655ms/step - loss: 0.6932 - accuracy: 0.4844 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 74/100
# 12/12 [==============================] - 8s 691ms/step - loss: 0.6929 - accuracy: 0.5212 - val_loss: 0.6929 - val_accuracy: 0.5104
# Epoch 75/100
# 12/12 [==============================] - 9s 730ms/step - loss: 0.6927 - accuracy: 0.5212 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 76/100
# 12/12 [==============================] - 9s 722ms/step - loss: 0.6927 - accuracy: 0.5182 - val_loss: 0.6940 - val_accuracy: 0.4896
# Epoch 77/100
# 12/12 [==============================] - 7s 617ms/step - loss: 0.6925 - accuracy: 0.5184 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 78/100
# 12/12 [==============================] - 7s 621ms/step - loss: 0.6918 - accuracy: 0.5326 - val_loss: 0.6931 - val_accuracy: 0.5104
# Epoch 79/100
# 12/12 [==============================] - 8s 642ms/step - loss: 0.6920 - accuracy: 0.5260 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 80/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.6910 - accuracy: 0.5382 - val_loss: 0.6948 - val_accuracy: 0.4896
# Epoch 81/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.6905 - accuracy: 0.5382 - val_loss: 0.6964 - val_accuracy: 0.4896
# Epoch 82/100
# 12/12 [==============================] - 7s 623ms/step - loss: 0.6927 - accuracy: 0.5184 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 83/100
# 12/12 [==============================] - 7s 614ms/step - loss: 0.6915 - accuracy: 0.5354 - val_loss: 0.6949 - val_accuracy: 0.5000
# Epoch 84/100
# 12/12 [==============================] - 7s 618ms/step - loss: 0.6893 - accuracy: 0.5241 - val_loss: 0.7045 - val_accuracy: 0.5104
# Epoch 85/100
# 12/12 [==============================] - 8s 628ms/step - loss: 0.6956 - accuracy: 0.5212 - val_loss: 0.6937 - val_accuracy: 0.5104
# Epoch 86/100
# 12/12 [==============================] - 8s 646ms/step - loss: 0.6922 - accuracy: 0.5312 - val_loss: 0.6957 - val_accuracy: 0.4896
# Epoch 87/100
# 12/12 [==============================] - 7s 614ms/step - loss: 0.6916 - accuracy: 0.5297 - val_loss: 0.6967 - val_accuracy: 0.4896
# Epoch 88/100
# 12/12 [==============================] - 7s 611ms/step - loss: 0.6924 - accuracy: 0.5241 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 89/100
# 12/12 [==============================] - 7s 616ms/step - loss: 0.6912 - accuracy: 0.5467 - val_loss: 0.6941 - val_accuracy: 0.5104
# Epoch 90/100
# 12/12 [==============================] - 8s 642ms/step - loss: 0.6927 - accuracy: 0.5241 - val_loss: 0.6975 - val_accuracy: 0.4896
# Epoch 91/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.6913 - accuracy: 0.5297 - val_loss: 0.6944 - val_accuracy: 0.5000
# Epoch 92/100
# 12/12 [==============================] - 8s 658ms/step - loss: 0.6915 - accuracy: 0.5286 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 93/100
# 12/12 [==============================] - 7s 618ms/step - loss: 0.6926 - accuracy: 0.5156 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 94/100
# 12/12 [==============================] - 7s 617ms/step - loss: 0.7041 - accuracy: 0.5354 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 95/100
# 12/12 [==============================] - 7s 608ms/step - loss: 0.6911 - accuracy: 0.5354 - val_loss: 0.6964 - val_accuracy: 0.4896
# Epoch 96/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.7037 - accuracy: 0.5326 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 97/100
# 12/12 [==============================] - 7s 620ms/step - loss: 0.6924 - accuracy: 0.5241 - val_loss: 0.6936 - val_accuracy: 0.4896
# Epoch 98/100
# 12/12 [==============================] - 7s 613ms/step - loss: 0.6924 - accuracy: 0.5241 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 99/100
# 12/12 [==============================] - 8s 649ms/step - loss: 0.6924 - accuracy: 0.5269 - val_loss: 0.6937 - val_accuracy: 0.4896
# Epoch 100/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.6927 - accuracy: 0.5241 - val_loss: 0.6929 - val_accuracy: 0.5104

# %%
class_names = ['cat', 'dog']
validation, label_batch  = next(iter(valid_generator))
prediction_values = model.predict(validation)
prediction_values = np.argmax(prediction_values, axis=1)

fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(8):
    ax = fig.add_subplot(2, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(validation[i,:],cmap=plt.cm.gray_r, interpolation='nearest')
  
    if prediction_values[i] == np.argmax(label_batch[i]):
        ax.text(3, 17, class_names[prediction_values[i]], color='yellow', fontsize=14)
    else:
        ax.text(3, 17, class_names[prediction_values[i]], color='red', fontsize=14)

# %%
#6.1.4 VGGNet

# %%
#pip install opencv-python
# %load_ext tensorboard

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
class VGG19(Sequential):
    def __init__(self, input_shape):
        super().__init__()

        self.add(Conv2D(64, kernel_size=(3,3), padding= 'same',
                        activation= 'relu', input_shape= input_shape))
        self.add(Conv2D(64, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(128, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(128, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Flatten())
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dropout(0.5))
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dropout(0.5))
        self.add(Dense(1000, activation= 'softmax'))

        self.compile(optimizer= tf.keras.optimizers.Adam(0.003),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %%
model = VGG19(input_shape=(224, 224, 3))
model.summary()
# Out:
# Model: "vg_g19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %%
# vgg19_weights_tf_dim_ordering_tf_kernels.h5 파일은 깃허브 Readme 파일에 안내된 링크에서 내려받아 chap6 > data 폴더에 넣어주세요.

model.load_weights("../chap6/data/vgg19_weights_tf_dim_ordering_tf_kernels.h5")

# %%
classes= {282: 'cat',
 681: 'notebook, notebook computer',
 970: 'alp'}

# %%
image1=cv2.imread('../chap6/data/labtop.jpg')
#image1=cv2.imread('../chap6/data/starrynight.jpeg')
#image1=cv2.imread('../chap6/data/cat.jpg')
image1 = cv2.resize(image1, (224, 224))
plt.figure()
plt.imshow(image1)
image1 = image1[np.newaxis, :]
predicted_value = model.predict(image1)
predicted_value = np.argmax(predicted_value)
plt.title(classes[predicted_value])

# %%
#6.1.6 ResNset

# %%
def res_identity(x, filters): 
  x_skip = x 
  f1, f2 = filters

  x = Conv2D(f1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)

  x = Add()([x, x_skip])
  x = Activation(activations.relu)(x)

  return x

# %%
def res_conv(x, s, filters):
  x_skip = x
  f1, f2 = filters

  x = Conv2D(f1, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x)
  # when s = 2 then it is like downsizing the feature map
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)

  x_skip = Conv2D(f2, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x_skip)
  x_skip = BatchNormalization()(x_skip)
 
  x = Add()([x, x_skip])
  x = Activation(activations.relu)(x)

  return x

# %%
input_shape=(4,28,28,3)
x = tf.random.normal(input_shape)
print(x.shape)
y = tf.keras.layers.Conv2D(2, 3, activation='relu', input_shape=input_shape[1:])(x)
print(input_shape[1:])
print(y.shape)
# Out:
# (4, 28, 28, 3)
# (28, 28, 3)
# (4, 26, 26, 2)
